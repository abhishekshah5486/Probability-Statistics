# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekshah5486/Probability-Statistics/blob/main/Pandas_CaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 82.0MB/s]

# %%
data = pd.read_csv("movies.csv")

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
data.tail(2)
# Out:
#       Unnamed: 0     id  budget  popularity  revenue        title  \
# 1463        4749  48376       0           3        0      Slacker
# 1464        4768  48395  220000          14  2040920  El Mariachi
#
#       vote_average  vote_count  director_id  year month     day
# 1463           6.4          77         5535  1990   Jul  Friday
# 1464           6.6         238         5097  1992   Sep  Friday

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
  data.describe()
# Out:
#         Unnamed: 0            id        budget   popularity       revenue  \
# count  1465.000000   1465.000000  1.465000e+03  1465.000000  1.465000e+03
# mean   1627.391809  45225.191126  4.802295e+07    30.855973  1.432539e+08
# std    1187.182894   1189.096396  4.935541e+07    34.845214  2.064918e+08
# min       0.000000  43597.000000  0.000000e+00     0.000000  0.000000e+00
# 25%     639.000000  44236.000000  1.400000e+07    11.000000  1.738013e+07
# 50%    1425.000000  45022.000000  3.300000e+07    23.000000  7.578164e+07
# 75%    2393.000000  45990.000000  6.600000e+07    41.000000  1.792469e+08
# max    4768.000000  48395.000000  3.800000e+08   724.000000  2.787965e+09
#
#        vote_average    vote_count  director_id         year
# count   1465.000000   1465.000000  1465.000000  1465.000000
# mean       6.368191   1146.396587  5040.192491  2002.615017
# std        0.818033   1578.077438   258.059631     8.680141
# min        3.000000      1.000000  4762.000000  1976.000000
# ...

# %%
 data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
data['vote_average']
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       5.9
#        ...
# 1460    7.9
# 1461    7.4
# 1462    6.0
# 1463    6.4
# 1464    6.6
# Name: vote_average, Length: 1465, dtype: float64

# %%
data['revenue']
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        890871626
#            ...
# 1460        321952
# 1461       3151130
# 1462             0
# 1463             0
# 1464       2040920
# Name: revenue, Length: 1465, dtype: int64

# %%
data.revenue
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        890871626
#            ...
# 1460        321952
# 1461       3151130
# 1462             0
# 1463             0
# 1464       2040920
# Name: revenue, Length: 1465, dtype: int64

# %%
cols = ['revenue', 'vote_average', 'budget']
data[cols]
# Out:
#          revenue  vote_average     budget
# 0     2787965087           7.2  237000000
# 1      961000000           6.9  300000000
# 2      880674609           6.3  245000000
# 3     1084939099           7.6  250000000
# 4      890871626           5.9  258000000
# ...          ...           ...        ...
# 1460      321952           7.9          0
# 1461     3151130           7.4      27000
# 1462           0           6.0          0
# 1463           0           6.4          0
# 1464     2040920           6.6     220000
#
# [1465 rows x 3 columns]

# %%
data.revenue.min()
# Out:
# 0

# %%
data['revenue'].min()
# Out:
# 0

# %%
data.budget.min()
# Out:
# 0

# %%
data.budget.max()
# Out:
# 380000000

# %%
data.vote_average
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       5.9
#        ...
# 1460    7.9
# 1461    7.4
# 1462    6.0
# 1463    6.4
# 1464    6.6
# Name: vote_average, Length: 1465, dtype: float64

# %%
mask = data['vote_average'] > 7

# %%
mask
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[mask]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 3              3  43600  250000000         112  1084939099
# 14            19  43616  250000000         120   956019788
# 16            22  43619  250000000          94   958400000
# 19            25  43622  200000000         100  1845034188
# ...          ...    ...        ...         ...         ...
# 1456        4694  48321      10000          20     7000000
# 1457        4696  48323          0           5           0
# 1458        4708  48335      60000          27     3221152
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# ...

# %%
# No. of movies releases in the year 2015 and an average vote of > 7
data[(data['year']==2015) & (data['vote_average']>7)].shape
# Out:
# (11, 12)

# %%
# No. of movies releases in the year 2015 and an average vote of > 7 = 12

# %%
data.sort_values('vote_average', ascending = False).head(5)
# Out:
#       Unnamed: 0     id     budget  popularity     revenue             title  \
# 1284        3232  46829    8000000         121   213928762      Pulp Fiction
# 383          662  44259   63000000         146   100853753        Fight Club
# 901         1818  45415   22000000         104   321365567  Schindler's List
# 459          809  44406   55000000         138   677945399      Forrest Gump
# 45            65  43662  185000000         187  1004558444   The Dark Knight
#
#       vote_average  vote_count  director_id  year month        day
# 1284           8.3        8428         4927  1994   Oct   Saturday
# 383            8.3        9413         4829  1999   Oct     Friday
# 901            8.3        4329         4799  1993   Nov     Monday
# 459            8.2        7927         4804  1994   Jul  Wednesday
# 45             8.2       12002         4765  2008   Jul  Wednesday

# %%
data.sort_values('vote_average').tail(5)
# Out:
#       Unnamed: 0     id     budget  popularity     revenue             title  \
# 45            65  43662  185000000         187  1004558444   The Dark Knight
# 459          809  44406   55000000         138   677945399      Forrest Gump
# 383          662  44259   63000000         146   100853753        Fight Club
# 901         1818  45415   22000000         104   321365567  Schindler's List
# 1284        3232  46829    8000000         121   213928762      Pulp Fiction
#
#       vote_average  vote_count  director_id  year month        day
# 45             8.2       12002         4765  2008   Jul  Wednesday
# 459            8.2        7927         4804  1994   Jul  Wednesday
# 383            8.3        9413         4829  1999   Oct     Friday
# 901            8.3        4329         4799  1993   Nov     Monday
# 1284           8.3        8428         4927  1994   Oct   Saturday

# %%
data.sort_values(by=['year'])
# Out:
#       Unnamed: 0     id     budget  popularity    revenue  \
# 1427        4325  47934    1300000          58   28262574
# 912         1838  45435    2800000          25   60922980
# 1379        3809  47409    3800000          17   23689877
# 1357        3667  47265    5000000          11          0
# 997         2087  45684   20000000          52  303788635
# ...          ...    ...        ...         ...        ...
# 1189        2742  46339   17000000          60  119100758
# 225          370  43967   90000000          51  334901337
# 1440        4540  48155          0           0          0
# 1073        2325  45922   18000000          16   88923251
# 135          218  43815  120000000          62  415484914
#
#                                    title  vote_average  vote_count  \
# 1427                         Taxi Driver           8.0        2535
# 912                             The Omen           7.2         476
# ...

# %%
data.sort_values(by=['year','vote_average'])
# Out:
#       Unnamed: 0     id     budget  popularity    revenue  \
# 912         1838  45435    2800000          25   60922980
# 1379        3809  47409    3800000          17   23689877
# 1427        4325  47934    1300000          58   28262574
# 1176        2693  46290          0           3          0
# 1357        3667  47265    5000000          11          0
# ...          ...    ...        ...         ...        ...
# 54            78  43675  175000000          94  966550600
# 225          370  43967   90000000          51  334901337
# 519          941  44538   50000000          42   69411370
# 617         1160  44757   40000000          68  320170008
# 1344        3584  47181    5000000          22   24804129
#
#                                           title  vote_average  vote_count  \
# 912                                    The Omen           7.2         476
# 1379                                    Network           7.7         381
# ...

# %%
profit = data['revenue'] - data['budget']
profit
# Out:
# 0       2550965087
# 1        661000000
# 2        635674609
# 3        834939099
# 4        632871626
#            ...
# 1460        321952
# 1461       3124130
# 1462             0
# 1463             0
# 1464       1820920
# Length: 1465, dtype: int64

# %%
data['Profit'] = profit

# %%
data.head(5)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit
# 0         4762  2009   Dec  Thursday  2550965087
# 1         4763  2007   May  Saturday   661000000
# 2         4764  2015   Oct    Monday   635674609
# ...

# %%
data.sort_values(by=['Profit'], ascending = False).head()
# Out:
#      Unnamed: 0     id     budget  popularity     revenue  \
# 0             0  43597  237000000         150  2787965087
# 19           25  43622  200000000         100  1845034188
# 30           44  43641  190000000         102  1506249360
# 199         329  43926   94000000         123  1118888979
# 36           52  43649  195000000          28  1123746996
#
#                                              title  vote_average  vote_count  \
# 0                                           Avatar           7.2       11800
# 19                                         Titanic           7.5        7562
# 30                                       Furious 7           7.3        4176
# 199  The Lord of the Rings: The Return of the King           8.1        8064
# 36                  Transformers: Dark of the Moon           6.1        3299
#
#      director_id  year month        day      Profit
# 0           4762  2009   Dec   Thursday  2550965087
# ...

# %%
data['ROI'] = np.round(data['revenue']/data['budget'],2)*100
data['ROI']
# Out:
# 0        1176.0
# 1         320.0
# 2         359.0
# 3         434.0
# 4         345.0
#          ...
# 1460        inf
# 1461    11671.0
# 1462        NaN
# 1463        NaN
# 1464      928.0
# Name: ROI, Length: 1465, dtype: float64

# %%
data.sort_values(by=['ROI'], ascending=False)
# Out:
#       Unnamed: 0     id  budget  popularity    revenue                  title  \
# 195          321  43918       0          16  104907746           The Campaign
# 599         1126  44723       0          26   73100172    Here Comes the Boom
# 1315        3407  47004       0          21    7000000  High School Musical 2
# 1313        3404  47001       0          14   41410568             Pale Rider
# 1293        3270  46867       0           5   25966555            Howards End
# ...          ...    ...     ...         ...        ...                    ...
# 1453        4668  48294       0           6          0    She's Gotta Have It
# 1457        4696  48323       0           5          0             The Mighty
# 1459        4732  48359       0           2          0      George Washington
# 1462        4748  48375       0           7          0                Rampage
# 1463        4749  48376       0           3          0                Slacker
#
# ...

# %%
data_roi = data[data['ROI']<1000000000]

# %%
data_roi.sort_values(by=['ROI'], ascending=False)
# Out:
#       Unnamed: 0     id    budget  popularity    revenue           title  \
# 1456        4694  48321     10000          20    7000000      Eraserhead
# 1450        4642  48267    400000          33  100000000         Mad Max
# 1102        2409  46006    300000          30   70000000       Halloween
# 1461        4743  48370     27000          19    3151130          Clerks
# 1424        4282  47888   1200000          63  103911669             Saw
# ...          ...    ...       ...         ...        ...             ...
# 586         1085  44682  45000000          11          0    Multiplicity
# 1236        2948  46545  11000000           4          0      Vera Drake
# 746         1456  45053  35000000           9          0  Bound by Honor
# 1278        3192  46789   9000000           8          0   Two Evil Eyes
# 757         1489  45086  33000000           9          0     Pushing Tin
#
#       vote_average  vote_count  director_id  year month        day     Profit  \
# ...

# %%
data.iloc[0]
# Out:
# Unnamed: 0               0
# id                   43597
# budget           237000000
# popularity             150
# revenue         2787965087
# title               Avatar
# vote_average           7.2
# vote_count           11800
# director_id           4762
# year                  2009
# month                  Dec
# day               Thursday
# Profit          2550965087
# ROI                 1176.0
# Name: 0, dtype: object

# %%
data.iloc[1:5] #data.iloc upper index is not included
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day     Profit    ROI
# 1         4763  2007   May  Saturday  661000000  320.0
# 2         4764  2015   Oct    Monday  635674609  359.0
# 3         4765  2012   Jul    Monday  834939099  434.0
# 4         4767  2007   May   Tuesday  632871626  345.0

# %%
data.loc[1:5] #data.loc upper index is also included
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
#
#                                       title  vote_average  vote_count  \
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
# 5        Batman v Superman: Dawn of Justice           5.7        7004
#
#    director_id  year month        day     Profit    ROI
# 1         4763  2007   May   Saturday  661000000  320.0
# 2         4764  2015   Oct     Monday  635674609  359.0
# ...

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit     ROI
# 0         4762  2009   Dec  Thursday  2550965087  1176.0
# 1         4763  2007   May  Saturday   661000000   320.0
# ...

# %%
rowDrop = data.drop(1, axis=0)
rowDrop.iloc[1:4]
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                    title  vote_average  vote_count  director_id  year month  \
# 2                Spectre           6.3        4466         4764  2015   Oct
# 3  The Dark Knight Rises           7.6        9106         4765  2012   Jul
# 4           Spider-Man 3           5.9        3576         4767  2007   May
#
#        day     Profit    ROI
# 2   Monday  635674609  359.0
# 3   Monday  834939099  434.0
# 4  Tuesday  632871626  345.0

# %%
data.drop('Unnamed: 0', axis=1).head(5)
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit     ROI
# 0         4762  2009   Dec  Thursday  2550965087  1176.0
# 1         4763  2007   May  Saturday   661000000   320.0
# 2         4764  2015   Oct    Monday   635674609   359.0
# ...

# %%
data.drop(columns=['Unnamed: 0', 'day'], axis=1).head(5)
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month      Profit     ROI
# 0         4762  2009   Dec  2550965087  1176.0
# 1         4763  2007   May   661000000   320.0
# 2         4764  2015   Oct   635674609   359.0
# 3         4765  2012   Jul   834939099   434.0
# ...

# %%
data.drop(columns=['Unnamed: 0', 'day'], axis=1, inplace = True)

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month      Profit     ROI
# 0         4762  2009   Dec  2550965087  1176.0
# 1         4763  2007   May   661000000   320.0
# 2         4764  2015   Oct   635674609   359.0
# 3         4765  2012   Jul   834939099   434.0
# ...

# %%
data.groupby(by='year').count()
# Out:
#       id  budget  popularity  revenue  title  vote_average  vote_count  \
# year
# 1976   3       3           3        3      3             3           3
# 1977   6       6           6        6      6             6           6
# 1978   5       5           5        5      5             5           5
# 1979   4       4           4        4      4             4           4
# 1980   8       8           8        8      8             8           8
# 1981  11      11          11       11     11            11          11
# 1982  10      10          10       10     10            10          10
# 1983   9       9           9        9      9             9           9
# 1984  10      10          10       10     10            10          10
# 1985  14      14          14       14     14            14          14
# 1986  11      11          11       11     11            11          11
# 1987  12      12          12       12     12            12          12
# ...

# %%
# Number of movies directed by each director
data.groupby(by='director_id').count()
# Out:
#              id  budget  popularity  revenue  title  vote_average  vote_count  \
# director_id
# 4762          7       7           7        7      7             7           7
# 4763          7       7           7        7      7             7           7
# 4764          7       7           7        7      7             7           7
# 4765          8       8           8        8      8             8           8
# 4767         11      11          11       11     11            11          11
# ...          ..     ...         ...      ...    ...           ...         ...
# 5894          5       5           5        5      5             5           5
# 5951          5       5           5        5      5             5           5
# 5970          6       6           6        6      6             6           6
# 6056          5       5           5        5      5             5           5
# 6204          5       5           5        5      5             5           5
#
# ...

# %%
data.groupby(by='director_id').count().sort_values(by=['title'], ascending=False)
#Director with id 4799 made the highest number of movies
# Out:
#              id  budget  popularity  revenue  title  vote_average  vote_count  \
# director_id
# 4799         26      26          26       26     26            26          26
# 4809         19      19          19       19     19            19          19
# 5087         19      19          19       19     19            19          19
# 5457         18      18          18       18     18            18          18
# 4779         16      16          16       16     16            16          16
# ...          ..     ...         ...      ...    ...           ...         ...
# 5105          5       5           5        5      5             5           5
# 4849          5       5           5        5      5             5           5
# 5096          5       5           5        5      5             5           5
# 5088          5       5           5        5      5             5           5
# 6204          5       5           5        5      5             5           5
#
# ...

# %%
# Name of the director with the highest number of movies
data.groupby(by='director_id').count().sort_values(by=['title'], ascending=False)
