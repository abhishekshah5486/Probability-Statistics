# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekshah5486/Probability-Statistics/blob/main/Sales_CaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown 1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# To: /content/sales.csv
# 100% 94.9M/94.9M [00:00<00:00, 117MB/s]

# %%
df = pd.read_csv('sales.csv')

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
salesDate = df[df['InvoiceDate'].str.split().str[0] == '2011-06-22']

# %%
salesDate
# Out:
#        Invoice StockCode                    Description  Quantity  \
# 761424  557667     22730     ALARM CLOCK BAKELIKE IVORY        12
# 761425  557667    85232D  SET/3 DECOUPAGE STACKING TINS         3
# 761426  557667     22727      ALARM CLOCK BAKELIKE RED         24
# 761427  557667     23084             RABBIT NIGHT LIGHT        24
# 761428  557667     22726     ALARM CLOCK BAKELIKE GREEN        24
# ...        ...       ...                            ...       ...
# 762436  557793     82567      AIRLINE LOUNGE,METAL SIGN         1
# 762437  557793     21172              PARTY METAL SIGN          2
# 762438  557793     22426         ENAMEL WASH BOWL CREAM         1
# 762439  557793     22429     ENAMEL MEASURING JUG CREAM         1
# 762440  557793     22425          ENAMEL COLANDER CREAM         1
#
#                 InvoiceDate  Price  Customer ID         Country
# 761424  2011-06-22 08:30:00   3.75      15606.0  United Kingdom
# ...

# %%
# uniqueSales = salesDate['Customer ID']
# uniqueSales.sort_values(ascending = False)

# %%
temp = salesDate.sort_values(by=['Customer ID'], ascending=False)

# %%
sales = temp[temp['Customer ID'].notna()]

# %%
temp[temp['Customer ID'].notna()]['Customer ID'].unique()
# Out:
# array([18155., 17877., 17828., 17669., 17585., 17389., 16987., 16966.,
#        16841., 16626., 16566., 16458., 16422., 16247., 16214., 16180.,
#        16114., 15840., 15810., 15804., 15750., 15606., 15601., 15550.,
#        15194., 15059., 15041., 14998., 14911., 14733., 14643., 14640.,
#        14606., 14527., 14463., 14422., 14364., 14214., 14156., 14099.,
#        14092., 14088., 13849., 13780., 13695., 13611., 13477., 13420.,
#        13089., 13004., 12901., 12798., 12748., 12684., 12674., 12432.,
#        12379.])

# %%
ans = len(sales['Customer ID'].unique())

# %%
ans
# Out:
# 57

# %%
salesFrance = df[df['Country']=='France']
salesFrance
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 71       489439     22065     CHRISTMAS PUDDING TRINKET POT         12
# 72       489439     22138      BAKING SET 9 PIECE RETROSPOT          9
# 73       489439     22139  RETRO SPOT TEA SET CERAMIC 11 PC          9
# 74       489439     22352   LUNCHBOX WITH CUTLERY RETROSPOT         12
# 75       489439    85014A   BLACK/BLUE DOTS RUFFLED UMBRELLA         3
# ...         ...       ...                                ...       ...
# 1067366  581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138      BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                            POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country
# 71       2009-12-01 09:28:00   1.45      12682.0  France
# ...

# %%
salesFrance['date'] = salesFrance['InvoiceDate'].str.split().str[0]
salesFrance['sales'] = salesFrance['Quantity'] * salesFrance['Price']
salesFrance
# Out:
# <ipython-input-46-4dc5c65907b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salesFrance['date'] = salesFrance['InvoiceDate'].str.split().str[0]
# <ipython-input-46-4dc5c65907b3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salesFrance['sales'] = salesFrance['Quantity'] * salesFrance['Price']
#         Invoice StockCode                        Description  Quantity  \
# 71       489439     22065     CHRISTMAS PUDDING TRINKET POT         12
# ...

# %%
temp = salesFrance.groupby('date').sum('sales')
temp
# Out:
#             Quantity   Price  Customer ID  TotalSales    sales
# date
# 2009-12-01       660  134.25     515863.0     1024.29  1024.29
# 2009-12-02       261  120.02     360845.0      549.33   549.33
# 2009-12-03      -118   98.15     420487.0     -143.90  -143.90
# 2009-12-04       233  184.73     406281.0      636.90   636.90
# 2009-12-06       388   76.38     289409.0      817.44   817.44
# ...              ...     ...          ...         ...      ...
# 2011-12-05       477  106.73     443905.0      797.48   797.48
# 2011-12-06       787  268.48    1002259.0     1403.94  1403.94
# 2011-12-07       561  136.98     491377.0     1117.62  1117.62
# 2011-12-08        18   52.90      74880.0      146.70   146.70
# 2011-12-09       106   62.50     202880.0      267.45   267.45
#
# [372 rows x 5 columns]

# %%
temp.sort_values(by=['sales'], ascending=False)
# Out:
#             Quantity   Price  Customer ID  TotalSales     sales
# date
# 2010-08-09     87547  160.85    1132578.0    12726.01  12726.01
# 2011-10-28      5246  257.26     798693.0     8990.46   8990.46
# 2010-05-06      5506  465.52    2198297.0     8490.90   8490.90
# 2011-03-31      3349  214.69     914777.0     5593.59   5593.59
# 2010-11-19      2879  613.59    1756909.0     5084.89   5084.89
# ...              ...     ...          ...         ...       ...
# 2009-12-10       -30   32.20      99496.0     -118.90   -118.90
# 2009-12-03      -118   98.15     420487.0     -143.90   -143.90
# 2010-05-28       -60    3.80      50572.0     -364.80   -364.80
# 2010-08-05      -120   42.15     100659.0     -421.40   -421.40
# 2010-09-28    -87167    6.81     642465.0   -11880.84 -11880.84
#
# [372 rows x 5 columns]

# %%
# Most selling product
df.groupby('Description').sum().sort_values(by=['Quantity'], ascending=False)
# Out:
# <ipython-input-53-9b584a0ef544>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Description').sum().sort_values(by=['Quantity'], ascending=False)
#                                     Quantity     Price  Customer ID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545    298.18   14628933.0
# WHITE HANGING HEART T-LIGHT HOLDER     93050  18488.35   82666326.0
# ASSORTED COLOUR BIRD ORNAMENT          81306   5483.78   42672530.0
# JUMBO BAG RED RETROSPOT                78090   8230.47   42448849.0
# BROCADE RING PURSE                     70700    317.63    6362283.0
# ...                                      ...       ...          ...
# Unsaleable, destroyed.                -15644      0.00          0.0
# missing                               -16467      0.00          0.0
# ...
